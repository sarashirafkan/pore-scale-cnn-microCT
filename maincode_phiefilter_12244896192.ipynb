# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/image/images.zip -d /content/images.zip
# !unzip -q images.zip

# %%
# !rm /content/images.zip

# %%
import os
A=os.listdir('/content')
A
# Out:
# ['.config', 'drive', 'images', 'sample_data']

# %%
import pandas as pd
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
s='/content/images/*'
path=glob.glob(s)
import re
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ]
    return sorted(data, key=alphanum_key)

path1=sorted_alphanumeric(path)
path1 = [item.replace('p','_') for item in path1]
data=pd.read_excel('/content/drive/MyDrive/image/data_c.xlsx')
data
len(path1)
print(path1)
type(path1)
path1=np.array(path1)
path1.shape
path1[0]
# Out:
# ['/content/images/C_1_1_1.raw', '/content/images/C_1_1_16.raw', '/content/images/C_1_1_31.raw', '/content/images/C_1_1_46.raw', '/content/images/C_1_1_61.raw', '/content/images/C_1_1_76.raw', '/content/images/C_1_1_91.raw', '/content/images/C_1_1_106.raw', '/content/images/C_1_1_121.raw', '/content/images/C_1_1_136.raw', '/content/images/C_1_1_151.raw', '/content/images/C_1_1_166.raw', '/content/images/C_1_1_181.raw', '/content/images/C_1_1_196.raw', '/content/images/C_1_1_211.raw', '/content/images/C_1_1_226.raw', '/content/images/C_1_1_241.raw', '/content/images/C_1_1_256.raw', '/content/images/C_1_1_271.raw', '/content/images/C_1_1_286.raw', '/content/images/C_1_1_301.raw', '/content/images/C_1_16_1.raw', '/content/images/C_1_16_16.raw', '/content/images/C_1_16_31.raw', '/content/images/C_1_16_46.raw', '/content/images/C_1_16_61.raw', '/content/images/C_1_16_76.raw', '/content/images/C_1_16_91.raw', '/content/images/C_1_16_106.raw', '/content/images/C_1_16_121.raw', '/content/images/C_1_16_136.raw', '/content/images/C_1_16_151.raw', '/content/images/C_1_16_166.raw', '/content/images/C_1_16_181.raw', '/content/images/C_1_16_196.raw', '/content/images/C_1_16_211.raw', '/content/images/C_1_16_226.raw', '/content/images/C_1_16_241.raw', '/content/images/C_1_16_256.raw', '/content/images/C_1_16_271.raw', '/content/images/C_1_16_286.raw', '/content/images/C_1_16_301.raw', '/content/images/C_1_31_1.raw', '/content/images/C_1_31_16.raw', '/content/images/C_1_31_31.raw', '/content/images/C_1_31_46.raw', '/content/images/C_1_31_61.raw', '/content/images/C_1_31_76.raw', '/content/images/C_1_31_91.raw', '/content/images/C_1_31_106.raw', '/content/images/C_1_31_121.raw', '/content/images/C_1_31_136.raw', '/content/images/C_1_31_151.raw', '/content/images/C_1_31_166.raw', '/content/images/C_1_31_181.raw', '/content/images/C_1_31_196.raw', '/content/images/C_1_31_211.raw', '/content/images/C_1_31_226.raw', '/content/images/C_1_31_241.raw', '/content/images/C_1_31_256.raw', '/content/images/C_1_31_271.raw', '/content/images/C_1_31_286.raw', '/content/images/C_1_31_301.raw', '/content/images/C_1_46_1.raw', '/content/images/C_1_46_16.raw', '/content/images/C_1_46_31.raw', '/content/images/C_1_46_46.raw', '/content/images/C_1_46_61.raw', '/content/images/C_1_46_76.raw', '/content/images/C_1_46_91.raw', '/content/images/C_1_46_106.raw', '/content/images/C_1_46_121.raw', '/content/images/C_1_46_136.raw', '/content/images/C_1_46_151.raw', '/content/images/C_1_46_166.raw', '/content/images/C_1_46_181.raw', '/content/images/C_1_46_196.raw', '/content/images/C_1_46_211.raw', '/content/images/C_1_46_226.raw', '/content/images/C_1_46_241.raw', '/content/images/C_1_46_256.raw', '/content/images/C_1_46_271.raw', '/content/images/C_1_46_286.raw', '/content/images/C_1_46_301.raw', '/content/images/C_1_61_1.raw', '/content/images/C_1_61_16.raw', '/content/images/C_1_61_31.raw', '/content/images/C_1_61_46.raw', '/content/images/C_1_61_61.raw', '/content/images/C_1_61_76.raw', '/content/images/C_1_61_91.raw', '/content/images/C_1_61_106.raw', '/content/images/C_1_61_121.raw', '/content/images/C_1_61_136.raw', '/content/images/C_1_61_151.raw', '/content/images/C_1_61_166.raw', '/content/images/C_1_61_181.raw', '/content/images/C_1_61_196.raw', '/content/images/C_1_61_211.raw', '/content/images/C_1_61_226.raw', '/content/images/C_1_61_241.raw', '/content/images/C_1_61_256.raw', '/content/images/C_1_61_271.raw', '/content/images/C_1_61_286.raw', '/content/images/C_1_61_301.raw', '/content/images/C_1_76_1.raw', '/content/images/C_1_76_16.raw', '/content/images/C_1_76_31.raw', '/content/images/C_1_76_46.raw', '/content/images/C_1_76_61.raw', '/content/images/C_1_76_76.raw', '/content/images/C_1_76_91.raw', '/content/images/C_1_76_106.raw', '/content/images/C_1_76_121.raw', '/content/images/C_1_76_136.raw', '/content/images/C_1_76_151.raw', '/content/images/C_1_76_166.raw', '/content/images/C_1_76_181.raw', '/content/images/C_1_76_196.raw', '/content/images/C_1_7 ...
# '/content/images/C_1_1_1.raw'

# %%
path1=np.array(path1)
data=np.array(data)

# %%
df=pd.DataFrame({'imgpath':path1,'Porosity':data[:,0],'throat radius':data[:,1],'pore radius':data[:,2],'pore_connection_number':data[:,3],'pore shape factor':data[:,4]})

# %%
df_new=df[df['Porosity'] <0.35 ]
df_new.shape
df_new
# Out:
#                                 imgpath  Porosity  throat radius  pore radius  \
# 0           /content/images/C_1_1_1.raw  0.200016       0.000009     0.000013
# 1          /content/images/C_1_1_16.raw  0.211707       0.000008     0.000012
# 2          /content/images/C_1_1_31.raw  0.233293       0.000008     0.000013
# 3          /content/images/C_1_1_46.raw  0.264409       0.000009     0.000014
# 4          /content/images/C_1_1_61.raw  0.277295       0.000009     0.000014
# ...                                 ...       ...            ...          ...
# 9256  /content/images/C_301_301_241.raw  0.136927       0.000008     0.000013
# 9257  /content/images/C_301_301_256.raw  0.136191       0.000008     0.000013
# 9258  /content/images/C_301_301_271.raw  0.147490       0.000008     0.000014
# 9259  /content/images/C_301_301_286.raw  0.161413       0.000008     0.000013
# 9260  /content/images/C_301_301_301.raw  0.179779       0.000009     0.000015
#
#       pore_connection_number  pore shape factor
# 0                    1.92857           0.037024
# 1                    2.25000           0.036642
# 2                    1.96875           0.038013
# 3                    2.18182           0.039828
# 4                    2.27273           0.038306
# ...                      ...                ...
# 9256                 2.35443           0.036514
# 9257                 2.12658           0.036236
# 9258                 2.17722           0.033896
# 9259                 2.18987           0.035108
# 9260                 1.97468           0.029493
#
# [7921 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
data1=np.array(df_new)
scaler = StandardScaler()
data1= scaler.fit_transform(data1[:,1:])
print(data1)
print(type(data1))
data1.shape
# Out:
# [[ 0.11455659  0.58493673  0.28969785 -0.82815281 -0.22691552]
#  [ 0.27058416 -0.34306756 -0.15901557 -0.0260099  -0.34020621]
#  [ 0.55866997 -0.05166937  0.52032542 -0.72788183  0.06680977]
#  ...
#  [-0.58645309 -0.39830083  0.62718527 -0.20763563 -1.1561657 ]
#  [-0.40063734  0.06434896  0.10229779 -0.17606699 -0.79601231]
#  [-0.15552552  0.3087704   1.25751387 -0.71308325 -2.46407987]]
# <class 'numpy.ndarray'>
# (7921, 5)

# %%
df=pd.DataFrame({'imgpath':df_new['imgpath'],'Porosity':data1[:,0],'throat radius':data1[:,1],'pore radius':data1[:,2],'pore_connection_number':data1[:,3],'pore shape factor':data1[:,4]})
df
# Out:
#                                 imgpath  Porosity  throat radius  pore radius  \
# 0           /content/images/C_1_1_1.raw  0.114557       0.584937     0.289698
# 1          /content/images/C_1_1_16.raw  0.270584      -0.343068    -0.159016
# 2          /content/images/C_1_1_31.raw  0.558670      -0.051669     0.520325
# 3          /content/images/C_1_1_46.raw  0.973943       0.745227     0.630089
# 4          /content/images/C_1_1_61.raw  1.145919       0.514543     1.057970
# ...                                 ...       ...            ...          ...
# 9256  /content/images/C_301_301_241.raw -0.727426      -0.487201     0.223571
# 9257  /content/images/C_301_301_256.raw -0.737249      -0.264275     0.454180
# 9258  /content/images/C_301_301_271.raw -0.586453      -0.398301     0.627185
# 9259  /content/images/C_301_301_286.raw -0.400637       0.064349     0.102298
# 9260  /content/images/C_301_301_301.raw -0.155526       0.308770     1.257514
#
#       pore_connection_number  pore shape factor
# 0                  -0.828153          -0.226916
# 1                  -0.026010          -0.340206
# 2                  -0.727882           0.066810
# 3                  -0.196156           0.606040
# 4                   0.030714           0.154056
# ...                      ...                ...
# 9256                0.234600          -0.378288
# 9257               -0.334010          -0.460952
# 9258               -0.207636          -1.156166
# 9259               -0.176067          -0.796012
# 9260               -0.713083          -2.464080
#
# [7921 rows x 6 columns]

# %%
data_t_general=df.sample(frac=0.9,random_state=1)
df_valid=data_t_general.sample(frac=0.15,random_state=2)
df_train=data_t_general.loc[~data_t_general.index.isin(df_valid.index)]
df_test =df.loc[~df.index.isin(data_t_general.index)]
len(df_train)
# Out:
# 6060

# %%
def Data_generator(df, batch_size, augment=False):

    while True:

            for start in range(0, df.shape[0], batch_size):
                x_batch_img = []
                y_batch=[]
                end = min(start + batch_size, df.shape[0])

                for idd in range(start,end):
                    img = open(np.array(df.imgpath)[idd],'rb').read()
                    img_1=np.frombuffer(img,dtype=np.uint8)
                    img_1=img_1.reshape(100,100,100,1)
                    Porosity=np.array(df.Porosity)[idd]
                    throat_radius=np.array(df['throat radius'])[idd]
                    pore_radius=np.array(df['pore radius'])[idd]
                    pore_connection_number=np.array(df.pore_connection_number)[idd]
                    pore_shape_factor=np.array(df['pore shape factor'])[idd]
                    y_1=np.concatenate((Porosity, throat_radius,pore_radius,pore_connection_number, pore_shape_factor),axis=None)
                    y=np.array([y_1])
                    x_batch_img.append(img_1)
                    y_batch.append(y)


                x_batch_img = np.array(x_batch_img)
                y_batch= np.array(y_batch)
                y_batch=y_batch.reshape(-1,5)
              #y_batch = to_categorical(y_batch,5)
                yield x_batch_img , y_batch

# %%
def Data_predict_generator(df, batch_size, augment=False):

    while True:

            for start in range(0, df.shape[0], batch_size):
                x_batch_img_2 = []

                end = min(start + batch_size, df.shape[0])

                for idd in range(start,end):
                    img = open(np.array(df.imgpath)[idd],'rb').read()
                    img_1=np.frombuffer(img,dtype=np.uint8)
                    img_1=img_1.reshape(100,100,100,1)
                    x_batch_img_2.append(img_1)



                x_batch_img_2 = np.array(x_batch_img_2)

              #y_batch = to_categorical(y_batch,5)
                yield x_batch_img_2

# %%
batch_size=10
train_gen= Data_generator(df_train,batch_size)
valid_gen= Data_generator(df_valid,batch_size)
train_gen_pre=Data_predict_generator(df_train,batch_size)
valid_gen_pre=Data_predict_generator(df_valid,batch_size)
test_gen= Data_generator(df_test,batch_size)
test_gen_pre=Data_predict_generator(df_test,batch_size)

# %%
import math
ntrain, nvalid, ntest = df_train.shape[0], df_valid.shape[0],  df_test.shape[0]
nbatches_train=math.ceil(df_train.shape[0]/batch_size)
nbatches_valid=math.ceil(df_valid.shape[0]/batch_size)
nbatches_test=math.ceil( df_test.shape[0]/batch_size)
nworkers=1

# %%
print(nbatches_valid,nbatches_train,nbatches_test)
# Out:
# 107 606 80

# %%
from keras.models import Sequential
from keras.layers import Conv3D,MaxPooling3D,Dropout,Flatten,Dense,BatchNormalization,ReLU
from tensorflow.keras import initializers
from keras.callbacks import *
import tensorflow as tf

# %%
model=Sequential()
model.add(Conv3D(12,kernel_size=(7,7,7),input_shape=(100,100,100,1),padding="same",activation='relu',kernel_initializer=initializers.RandomNormal(stddev=0.01),))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Conv3D(24,kernel_size=(5,5,5),activation='relu',padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.01)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Conv3D(48,kernel_size=(3,3,3),activation='relu',padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.01)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Conv3D(96,kernel_size=(3,3,3),activation='relu',padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.01)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Conv3D(192,kernel_size=(3,3,3),activation='relu',padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.01)))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2,2,2)))
#model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(1024,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(5))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 100, 100, 100, 1   4128
#                              2)
#
#  batch_normalization (Batch  (None, 100, 100, 100, 1   48
#  Normalization)              2)
#
#  max_pooling3d (MaxPooling3  (None, 50, 50, 50, 12)    0
#  D)
#
#  conv3d_1 (Conv3D)           (None, 50, 50, 50, 24)    36024
#
#  batch_normalization_1 (Bat  (None, 50, 50, 50, 24)    96
#  chNormalization)
#
#  max_pooling3d_1 (MaxPoolin  (None, 25, 25, 25, 24)    0
#  g3D)
#
#  conv3d_2 (Conv3D)           (None, 25, 25, 25, 48)    31152
#
#  batch_normalization_2 (Bat  (None, 25, 25, 25, 48)    192
#  chNormalization)
#
#  max_pooling3d_2 (MaxPoolin  (None, 12, 12, 12, 48)    0
#  g3D)
#
#  conv3d_3 (Conv3D)           (None, 12, 12, 12, 96)    124512
#
#  batch_normalization_3 (Bat  (None, 12, 12, 12, 96)    384
#  chNormalization)
#
#  max_pooling3d_3 (MaxPoolin  (None, 6, 6, 6, 96)       0
#  g3D)
#
#  conv3d_4 (Conv3D)           (None, 6, 6, 6, 192)      497856
#
#  batch_normalization_4 (Bat  (None, 6, 6, 6, 192)      768
#  chNormalization)
#
#  max_pooling3d_4 (MaxPoolin  (None, 3, 3, 3, 192)      0
#  g3D)
#
#  flatten (Flatten)           (None, 5184)              0
#
#  dense (Dense)               (None, 1024)              5309440
#
#  batch_normalization_5 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  batch_normalization_6 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 6538109 (24.94 MB)
# Trainable params: 6534293 (24.93 MB)
# Non-trainable params: 3816 (14.91 KB)
# _________________________________________________________________

# %%
import os
checkpoint_path="/content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-{epoch:03d}.ckpt"
#os.makedirs("/content/drive/MyDrive/image/porosity_filtering/training_5layers", exist_ok=True)
#ckpt_callback = ModelCheckpoint(filepath='/content/drive/MyDrive/image/porosity_filtering/training_model_5layers/weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss')
cp_callback=ModelCheckpoint(filepath=checkpoint_path,save_weights_only=True,verbose=1)

# %%
csvlogger=CSVLogger('/content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/Training_47.log')

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(opt,loss='mse',metrics=['mse'])

# %%
history=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger])
# Out:
# <ipython-input-22-2be0de0fe96b>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger])
# Epoch 1/200
#
# Epoch 1: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-001.ckpt
# 606/606 - 327s - loss: 1.9323 - mse: 1.9323 - val_loss: 0.7084 - val_mse: 0.7084 - 327s/epoch - 539ms/step
# Epoch 2/200
#
# Epoch 2: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-002.ckpt
# 606/606 - 322s - loss: 0.6868 - mse: 0.6868 - val_loss: 0.3530 - val_mse: 0.3530 - 322s/epoch - 531ms/step
# Epoch 3/200
#
# Epoch 3: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-003.ckpt
# 606/606 - 303s - loss: 0.4644 - mse: 0.4644 - val_loss: 0.5903 - val_mse: 0.5903 - 303s/epoch - 499ms/step
# Epoch 4/200
#
# Epoch 4: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-004.ckpt
# 606/606 - 322s - loss: 0.4080 - mse: 0.4080 - val_loss: 0.3332 - val_mse: 0.3332 - 322s/epoch - 531ms/step
# Epoch 5/200
#
# Epoch 5: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-005.ckpt
# 606/606 - 322s - loss: 0.3792 - mse: 0.3792 - val_loss: 0.7184 - val_mse: 0.7184 - 322s/epoch - 531ms/step
# Epoch 6/200
#
# Epoch 6: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-006.ckpt
# 606/606 - 322s - loss: 0.3517 - mse: 0.3517 - val_loss: 0.5907 - val_mse: 0.5907 - 322s/epoch - 531ms/step
# Epoch 7/200
#
# Epoch 7: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-007.ckpt
# 606/606 - 322s - loss: 0.3515 - mse: 0.3515 - val_loss: 2.8408 - val_mse: 2.8408 - 322s/epoch - 531ms/step
# Epoch 8/200
#
# Epoch 8: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-008.ckpt
# 606/606 - 322s - loss: 0.3241 - mse: 0.3241 - val_loss: 0.3564 - val_mse: 0.3564 - 322s/epoch - 531ms/step
# Epoch 9/200
#
# Epoch 9: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-009.ckpt
# 606/606 - 322s - loss: 0.3059 - mse: 0.3059 - val_loss: 0.3000 - val_mse: 0.3000 - 322s/epoch - 531ms/step
# Epoch 10/200
#
# Epoch 10: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-010.ckpt
# 606/606 - 303s - loss: 0.2815 - mse: 0.2815 - val_loss: 0.4926 - val_mse: 0.4926 - 303s/epoch - 500ms/step
# Epoch 11/200
#
# Epoch 11: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-011.ckpt
# 606/606 - 302s - loss: 0.2874 - mse: 0.2874 - val_loss: 1.2900 - val_mse: 1.2900 - 302s/epoch - 499ms/step
# Epoch 12/200
#
# Epoch 12: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-012.ckpt
# 606/606 - 322s - loss: 0.2619 - mse: 0.2619 - val_loss: 0.2980 - val_mse: 0.2980 - 322s/epoch - 531ms/step
# Epoch 13/200
#
# Epoch 13: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-013.ckpt
# 606/606 - 322s - loss: 0.2445 - mse: 0.2445 - val_loss: 0.2558 - val_mse: 0.2558 - 322s/epoch - 532ms/step
# Epoch 14/200
#
# Epoch 14: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-014.ckpt
# 606/606 - 322s - loss: 0.2410 - mse: 0.2410 - val_loss: 0.4071 - val_mse: 0.4071 - 322s/epoch - 531ms/step
# Epoch 15/200
#
# Epoch 15: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-015.ckpt
# 606/606 - 322s - loss: 0.2326 - mse: 0.2326 - val_loss: 0.2880 - val_mse: 0.2880 - 322s/epoch - 531ms/step
# Epoch 16/200
#
# Epoch 16: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-016.ckpt
# 606/606 - 303s - loss: 0.2248 - mse: 0.2248 - val_loss: 0.1875 - val_mse: 0.1875 - 303s/epoch - 499ms/step
# Epoch 17/200
#
# Epoch 17: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-017.ckpt
# 606/606 - 302s - loss: 0.2179 - mse: 0.2179 - val_loss: 0.2959 - val_mse: 0.2959 - 302s/epoch - 499ms/step
# Epoch 18/200
#
# Epoch 18: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-018.ckpt
# 606/606 - 321s - loss: 0.2130 - mse: 0.2130 - val_loss: 0.2481 - val_mse: 0.2481 - 321s/epoch - 530ms/step
# Epoch 19/200
#
# Epoch 19: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-019.ckpt
# 606/606 - 322s - loss: 0.2067 - mse: 0.2067 - val_loss: 0.2089 - val_mse: 0.2089 - 322s/epoch - 531ms/step
# Epoch 20/200
#
# Epoch 20: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-020.ckpt
# 606/606 - 302s - loss: 0.1987 - mse: 0.1987 - val_loss: 0.2272 - val_mse: 0.2272 - 302s/epoch - 499ms/step
# Epoch 21/200
#
# Epoch 21: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-021.ckpt
# 606/606 - 321s - loss: 0.1929 - mse: 0.1929 - val_loss: 0.4142 - val_mse: 0.4142 - 321s/epoch - 530ms/step
# Epoch 22/200
#
# Epoch 22: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-022.ckpt
# 606/606 - 302s - loss: 0.1924 - mse: 0.1924 - val_loss: 0.1706 - val_mse: 0.1706 - 302s/epoch - 499ms/step
# Epoch 23/200
#
# Epoch 23: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-023.ckpt
# 606/606 - 321s - loss: 0.1916 - mse: 0.1916 - val_loss: 0.1684 - val_mse: 0.1684 - 321s/epoch - 530ms/step
# Epoch 24/200
#
# Epoch 24: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-024.ckpt
# 606/606 - 302s - loss: 0.1875 - mse: 0.1875 - val_loss: 0.2595 - val_mse: 0.2595 - 302s/epoch - 499ms/step
# Epoch 25/200
#
# Epoch 25: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-025.ckpt
# 606/606 - 302s - loss: 0.1780 - mse: 0.1780 - val_loss: 0.1606 - val_mse: 0.1606 - 302s/epoch - 499ms/step
# Epoch 26/200
#
# Epoch 26: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-026.ckpt
# 606/606 - 322s - loss: 0.1753 - mse: 0.1753 - val_loss: 0.1809 - val_mse: 0.1809 - 322s/epoch - 531ms/step
# Epoch 27/200
#
# Epoch 27: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-027.ckpt
# 606/606 - 303s - loss: 0.1732 - mse: 0.1732 - val_loss: 0.2663 - val_mse: 0.2663 - 303s/epoch - 499ms/step
# Epoch 28/200
#
# Epoch 28: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-028.ckpt
# 606/606 - 321s - loss: 0.1717 - mse: 0.1717 - val_loss: 0.2032 - val_mse: 0.2032 - 321s/epoch - 530ms/step
# Epoch 29/200
#
# Epoch 29: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-029.ckpt
# 606/606 - 322s - loss: 0.1696 - mse: 0.1696 - val_loss: 0.2400 - val_mse: 0.2400 - 322s/epoch - 531ms/step
# Epoch 30/200
#
# Epoch 30: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-030.ckpt
# 606/606 - 322s - loss: 0.1707 - mse: 0.1707 - val_loss: 0.1588 - val_mse: 0.1588 - 322s/epoch - 531ms/step
# Epoch 31/200
#
# Epoch 31: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-031.ckpt
# 606/606 - 303s - loss: 0.1677 - mse: 0.1677 - val_loss: 0.2781 - val_mse: 0.2781 - 303s/epoch - 500ms/step
# Epoch 32/200
# 606/606 - 322s - loss: 0.1695 - mse: 0.1695 - val_loss: 0.2235 - val_mse: 0.2235 - 322s/epoch - 531ms/step
# Epoch 33/200
#
# Epoch 33: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-033.ckpt
# 606/606 - 322s - loss: 0.1650 - mse: 0.1650 - val_loss: 0.1944 - val_mse: 0.1944 - 322s/epoch - 531ms/step
# Epoch 34/200
#
# Epoch 34: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-034.ckpt
# 606/606 - 302s - loss: 0.1614 - mse: 0.1614 - val_loss: 0.1598 - val_mse: 0.1598 - 302s/epoch - 499ms/step
# Epoch 35/200
#
# Epoch 35: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-035.ckpt
# 606/606 - 321s - loss: 0.1598 - mse: 0.1598 - val_loss: 0.1806 - val_mse: 0.1806 - 321s/epoch - 530ms/step
# Epoch 36/200
#
# Epoch 36: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-036.ckpt
# 606/606 - 303s - loss: 0.1581 - mse: 0.1581 - val_loss: 0.1385 - val_mse: 0.1385 - 303s/epoch - 499ms/step
# Epoch 37/200
#
# Epoch 37: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-037.ckpt
# 606/606 - 302s - loss: 0.1588 - mse: 0.1588 - val_loss: 0.1390 - val_mse: 0.1390 - 302s/epoch - 499ms/step
# Epoch 38/200
#
# Epoch 38: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-038.ckpt
# 606/606 - 321s - loss: 0.1588 - mse: 0.1588 - val_loss: 0.1621 - val_mse: 0.1621 - 321s/epoch - 530ms/step
# Epoch 39/200
#
# Epoch 39: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-039.ckpt
# 606/606 - 303s - loss: 0.1568 - mse: 0.1568 - val_loss: 0.1568 - val_mse: 0.1568 - 303s/epoch - 500ms/step
# Epoch 40/200
#
# Epoch 40: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-040.ckpt
# 606/606 - 302s - loss: 0.1599 - mse: 0.1599 - val_loss: 0.1322 - val_mse: 0.1322 - 302s/epoch - 498ms/step
# Epoch 41/200
#
# Epoch 41: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-041.ckpt
# 606/606 - 304s - loss: 0.1542 - mse: 0.1542 - val_loss: 0.1512 - val_mse: 0.1512 - 304s/epoch - 501ms/step
# Epoch 42/200
#
# Epoch 42: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-042.ckpt
# 606/606 - 302s - loss: 0.1515 - mse: 0.1515 - val_loss: 0.1483 - val_mse: 0.1483 - 302s/epoch - 499ms/step
# Epoch 43/200
#
# Epoch 43: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-043.ckpt
# 606/606 - 302s - loss: 0.1513 - mse: 0.1513 - val_loss: 0.1343 - val_mse: 0.1343 - 302s/epoch - 499ms/step
# Epoch 44/200
#
# Epoch 44: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-044.ckpt
# 606/606 - 303s - loss: 0.1526 - mse: 0.1526 - val_loss: 0.1392 - val_mse: 0.1392 - 303s/epoch - 500ms/step
# Epoch 45/200
#
# Epoch 45: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-045.ckpt
# 606/606 - 303s - loss: 0.1498 - mse: 0.1498 - val_loss: 0.1386 - val_mse: 0.1386 - 303s/epoch - 499ms/step
# Epoch 46/200
#
# Epoch 46: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-046.ckpt
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-22-2be0de0fe96b> in <cell line: 1>()
# ----> 1 history=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2808             stacklevel=2,
#    2809         )
# -> 2810         return self.fit(
#    2811             generator,
#    2812             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/lib/io/file_io.py in flush(self)
#     219     """
#     220     if self._writable_file:
# --> 221       self._writable_file.flush()
#     222
#     223   def close(self):
#
# FailedPreconditionError: /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/Training_1.log; Transport endpoint is not connected

# %%
wieght='/content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-046.ckpt'
model.load_weights(wieght)

# %%
history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=46)
# Out:
# <ipython-input-25-6c890e2714d6>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=46)
# Epoch 47/200
#
# Epoch 47: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-047.ckpt
# 606/606 - 303s - loss: 0.1499 - mse: 0.1499 - val_loss: 0.1472 - val_mse: 0.1472 - 303s/epoch - 500ms/step
# Epoch 48/200
#
# Epoch 48: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/12,24,48,96,192/training_model_weights/cp-048.ckpt
# 606/606 - 321s - loss: 0.1486 - mse: 0.1486 - val_loss: 0.1586 - val_mse: 0.1586 - 321s/epoch - 530ms/step
# Epoch 49/200

# %%
wieght='/content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-048.ckpt'
model.load_weights(wieght)

# %%
history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=48)
# Out:
# Epoch 49/200
# <ipython-input-23-e9ea1891d4b1>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=48)
# Epoch 49: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-049.ckpt
# 606/606 - 461s - loss: 0.1498 - mse: 0.1498 - val_loss: 0.3884 - val_mse: 0.3884 - 461s/epoch - 761ms/step
# Epoch 50/200
#
# Epoch 50: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-050.ckpt
# 606/606 - 435s - loss: 0.1474 - mse: 0.1474 - val_loss: 0.1780 - val_mse: 0.1780 - 435s/epoch - 718ms/step
# Epoch 51/200
#
# Epoch 51: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-051.ckpt
# 606/606 - 434s - loss: 0.1493 - mse: 0.1493 - val_loss: 21.2912 - val_mse: 21.2912 - 434s/epoch - 716ms/step
# Epoch 52/200
#
# Epoch 52: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-052.ckpt
# 606/606 - 445s - loss: 0.1498 - mse: 0.1498 - val_loss: 0.4638 - val_mse: 0.4638 - 445s/epoch - 734ms/step
# Epoch 53/200
#
# Epoch 53: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-053.ckpt
# 606/606 - 430s - loss: 0.1467 - mse: 0.1467 - val_loss: 15.4296 - val_mse: 15.4296 - 430s/epoch - 709ms/step
# Epoch 54/200
#
# Epoch 54: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-054.ckpt
# 606/606 - 444s - loss: 0.1474 - mse: 0.1474 - val_loss: 18.3587 - val_mse: 18.3587 - 444s/epoch - 733ms/step
# Epoch 55/200
#
# Epoch 55: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-055.ckpt
# 606/606 - 444s - loss: 0.1466 - mse: 0.1466 - val_loss: 0.1690 - val_mse: 0.1690 - 444s/epoch - 732ms/step
# Epoch 56/200
#
# Epoch 56: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-056.ckpt
# 606/606 - 430s - loss: 0.1481 - mse: 0.1481 - val_loss: 0.2851 - val_mse: 0.2851 - 430s/epoch - 709ms/step
# Epoch 57/200

# %%
wieght='/content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-056.ckpt'
model.load_weights(wieght)

# %%
history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=56)
# Out:
# <ipython-input-23-af49b27af538>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=56)
# Epoch 57/200
#
# Epoch 57: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-057.ckpt
# 606/606 - 479s - loss: 0.1473 - mse: 0.1473 - val_loss: 0.2566 - val_mse: 0.2566 - 479s/epoch - 791ms/step
# Epoch 58/200
#
# Epoch 58: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-058.ckpt
# 606/606 - 450s - loss: 0.1459 - mse: 0.1459 - val_loss: 0.6713 - val_mse: 0.6713 - 450s/epoch - 742ms/step
# Epoch 59/200
#
# Epoch 59: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-059.ckpt
# 606/606 - 450s - loss: 0.1444 - mse: 0.1444 - val_loss: 0.3339 - val_mse: 0.3339 - 450s/epoch - 742ms/step
# Epoch 60/200
#
# Epoch 60: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-060.ckpt
# 606/606 - 450s - loss: 0.1450 - mse: 0.1450 - val_loss: 0.2575 - val_mse: 0.2575 - 450s/epoch - 742ms/step
# Epoch 61/200
#
# Epoch 61: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-061.ckpt
# 606/606 - 436s - loss: 0.1452 - mse: 0.1452 - val_loss: 3.5533 - val_mse: 3.5533 - 436s/epoch - 720ms/step
# Epoch 62/200
#
# Epoch 62: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-062.ckpt
# 606/606 - 436s - loss: 0.1460 - mse: 0.1460 - val_loss: 0.6014 - val_mse: 0.6014 - 436s/epoch - 719ms/step
# Epoch 63/200
#
# Epoch 63: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-063.ckpt
# 606/606 - 450s - loss: 0.1442 - mse: 0.1442 - val_loss: 23.3557 - val_mse: 23.3557 - 450s/epoch - 742ms/step
# Epoch 64/200

# %%
wieght='/content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-063.ckpt'
model.load_weights(wieght)

# %%
history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=63)
# Out:
# Epoch 64/200
# <ipython-input-24-b4a6fc5a6d59>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=63)
# Epoch 64: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-064.ckpt
# 606/606 - 523s - loss: 0.1421 - mse: 0.1421 - val_loss: 28.0699 - val_mse: 28.0699 - 523s/epoch - 863ms/step
# Epoch 65/200
#
# Epoch 65: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-065.ckpt
# 606/606 - 469s - loss: 0.1427 - mse: 0.1427 - val_loss: 0.4125 - val_mse: 0.4125 - 469s/epoch - 774ms/step
# Epoch 66/200
#
# Epoch 66: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-066.ckpt
# 606/606 - 469s - loss: 0.1428 - mse: 0.1428 - val_loss: 0.2861 - val_mse: 0.2861 - 469s/epoch - 774ms/step
# Epoch 67/200
#
# Epoch 67: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-067.ckpt
# 606/606 - 457s - loss: 0.1429 - mse: 0.1429 - val_loss: 0.1906 - val_mse: 0.1906 - 457s/epoch - 754ms/step
# Epoch 68/200

# %%
wieght='/content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-067.ckpt'
model.load_weights(wieght)

# %%
history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=67)
# Out:
# Epoch 68/200
# <ipython-input-23-2a4e7380357e>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1=model.fit_generator(train_gen, steps_per_epoch=nbatches_train, epochs=200, verbose=2, validation_data=valid_gen, validation_steps=nbatches_valid,callbacks=[cp_callback,csvlogger],initial_epoch=67)
# Epoch 68: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-068.ckpt
# 606/606 - 486s - loss: 0.1430 - mse: 0.1430 - val_loss: 0.2320 - val_mse: 0.2320 - 486s/epoch - 802ms/step
# Epoch 69/200
#
# Epoch 69: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-069.ckpt
# 606/606 - 445s - loss: 0.1436 - mse: 0.1436 - val_loss: 0.3225 - val_mse: 0.3225 - 445s/epoch - 734ms/step
# Epoch 70/200
#
# Epoch 70: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-070.ckpt
# 606/606 - 445s - loss: 0.1420 - mse: 0.1420 - val_loss: 0.3453 - val_mse: 0.3453 - 445s/epoch - 734ms/step
# Epoch 71/200
#
# Epoch 71: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-071.ckpt
# 606/606 - 445s - loss: 0.1444 - mse: 0.1444 - val_loss: 2.0035 - val_mse: 2.0035 - 445s/epoch - 734ms/step
# Epoch 72/200
#
# Epoch 72: saving model to /content/drive/MyDrive/image/porosity_filtering/filter_number/32,32,64,64,128/training_model_weights/cp-072.ckpt
# 606/606 - 445s - loss: 0.1414 - mse: 0.1414 - val_loss: 0.1618 - val_mse: 0.1618 - 445s/epoch - 734ms/step
# Epoch 73/200

# %%
#**********************************************predicting***********************************************

# %%
wieght='/content/drive/MyDrive/image/porosity_filtering/filter_number/training_model_weights/cp-192.ckpt'
model.load_weights(wieght)

# %%
model.evaluate_generator(test_gen, nbatches_test, workers=1)
# Out:
# <ipython-input-22-7a06d8a850cb>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(test_gen, nbatches_test, workers=1)
# [0.09834431111812592, 0.09834431111812592]

# %%
y=model.predict_generator(
    test_gen_pre,
    verbose=1,
    steps=nbatches_test,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False)
# Out:
# <ipython-input-23-e1afb12c7042>:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y=model.predict_generator(
# 80/80 [==============================] - 16s 201ms/step

# %%
y_1=pd.DataFrame({'porosity':((y[:,0]*df_new['Porosity'].std())+df_new['Porosity'].mean()),
                  'throat radius':((y[:,1]*df_new['throat radius'].std())+df_new['throat radius'].mean()),
                'pore radius':((y[:,2]*df_new['pore radius'].std())+df_new['pore radius'].mean()),
                'pore_connection_number':((y[:,3]*df_new.pore_connection_number.std())+df_new.pore_connection_number.mean()),
                 'pore shape factor':((y[:,4]*df_new['pore shape factor'].std())+df_new['pore shape factor'].mean())})

# %%
df_test_1=np.array(df_test)
df_test_2=pd.DataFrame({'porosity':((df_test_1[:,1]*df_new.Porosity.std())+df_new.Porosity.mean()),
                  'throat radius':((df_test_1[:,2]*df_new['throat radius'].std())+df_new['throat radius'].mean()),
                'pore radius':((df_test_1[:,3]*df_new['pore radius'].std())+df_new['pore radius'].mean()),
                'pore_connection_number':((df_test_1[:,4]*df_new.pore_connection_number.std())+df_new.pore_connection_number.mean()),
                 'pore shape factor':((df_test_1[:,5]*df_new['pore shape factor'].std())+df_new['pore shape factor'].mean())})

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['porosity'])
y_values = np.array(y_1['porosity'])
r_squared_porosity=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_porosity)
# Out:
# 0.9881865423293393

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['pore shape factor'])
y_values = np.array(y_1['pore shape factor'])
r_squared_pore_shape_factor=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_pore_shape_factor)
# Out:
# 0.7470157152532328

# %%
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['throat radius'])
y_values = np.array(y_1['throat radius'])
r_squared_throat_radius=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_throat_radius)
# Out:
# 0.9095026813394387

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['pore radius'])
y_values = np.array(y_1['pore radius'])
r_squared_pore_radius=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_pore_radius)
# Out:
# 0.9316546104720596

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['pore_connection_number'])
y_values = np.array(y_1['pore_connection_number'])
r_squared_pore_connection_number=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_pore_connection_number)
# Out:
# 0.9252950964446824

# %%
AVG=np.mean([r_squared_pore_connection_number,r_squared_pore_radius,r_squared_throat_radius,r_squared_pore_shape_factor,r_squared_porosity])
print(AVG)
# Out:
# 0.9003309291677505

# %%
wieght='/content/drive/MyDrive/image/porosity_filtering/filter_number/training_model_weights/cp-166.ckpt'
model.load_weights(wieght)

# %%
model.evaluate_generator(test_gen, nbatches_test, workers=1)
# Out:
# <ipython-input-21-7a06d8a850cb>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(test_gen, nbatches_test, workers=1)
# [0.10160204023122787, 0.10160204023122787]

# %%
y=model.predict_generator(
    test_gen_pre,
    verbose=1,
    steps=nbatches_test,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False)
# Out:
# <ipython-input-22-e1afb12c7042>:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y=model.predict_generator(
# 80/80 [==============================] - 15s 190ms/step

# %%
y_1=pd.DataFrame({'porosity':((y[:,0]*df_new['Porosity'].std())+df_new['Porosity'].mean()),
                  'throat radius':((y[:,1]*df_new['throat radius'].std())+df_new['throat radius'].mean()),
                'pore radius':((y[:,2]*df_new['pore radius'].std())+df_new['pore radius'].mean()),
                'pore_connection_number':((y[:,3]*df_new.pore_connection_number.std())+df_new.pore_connection_number.mean()),
                 'pore shape factor':((y[:,4]*df_new['pore shape factor'].std())+df_new['pore shape factor'].mean())})

# %%
df_test_1=np.array(df_test)
df_test_2=pd.DataFrame({'porosity':((df_test_1[:,1]*df_new.Porosity.std())+df_new.Porosity.mean()),
                  'throat radius':((df_test_1[:,2]*df_new['throat radius'].std())+df_new['throat radius'].mean()),
                'pore radius':((df_test_1[:,3]*df_new['pore radius'].std())+df_new['pore radius'].mean()),
                'pore_connection_number':((df_test_1[:,4]*df_new.pore_connection_number.std())+df_new.pore_connection_number.mean()),
                 'pore shape factor':((df_test_1[:,5]*df_new['pore shape factor'].std())+df_new['pore shape factor'].mean())})

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['porosity'])
y_values = np.array(y_1['porosity'])
r_squared_porosity=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_porosity)
# Out:
# 0.9882126571049973

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['pore shape factor'])
y_values = np.array(y_1['pore shape factor'])
r_squared_pore_shape_factor=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_pore_shape_factor)
# Out:
# 0.7349724337121906

# %%
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['throat radius'])
y_values = np.array(y_1['throat radius'])
r_squared_throat_radius=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_throat_radius)
# Out:
# 0.9048566837055144

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['pore radius'])
y_values = np.array(y_1['pore radius'])
r_squared_pore_radius=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_pore_radius)
# Out:
# 0.9303806633227897

# %%
#R^2_porosity
from sklearn.metrics import r2_score
x_values = np.array(df_test_2['pore_connection_number'])
y_values = np.array(y_1['pore_connection_number'])
r_squared_pore_connection_number=r2_score(x_values, y_values)
#orrelation_matrix = np.corrcoef(x_values, y_values)
#correlation_xy = correlation_matrix[0,1]
#r_squared_porosity = correlation_xy**2
print(r_squared_pore_connection_number)
# Out:
# 0.9267216172099928

# %%
AVG=np.mean([r_squared_pore_connection_number,r_squared_pore_radius,r_squared_throat_radius,r_squared_pore_shape_factor,r_squared_porosity])
print(AVG)
# Out:
# 0.8970288110110969
